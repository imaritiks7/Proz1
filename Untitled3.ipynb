# %% [markdown]
# <a href="https://colab.research.google.com/github/imaritiks7/Proz1/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculadora(numero1, numero2, numero3):
  if(numero3==1):
    return (numero1+numero2)
  elif(parametro3==2):
    return (parametro1-parametro2)
  elif(numero3==3):
    return (numero1*numero2)
  elif(numero3==4):
    return (numero1/numero2)

numero3=1
while(numero3!=0):
  print("Selecione a operação desejada: \n1: Soma \n2: Subtração \n3: Multiplicação \n4: Divisão \n0: Sair")
  numero3=int(input())
  if(numero3==0):
    print("Você saiu")
  elif(numero3>4):
    print("Essa opção não existe\n")
  else:
    print("Selecione o primero numero\n")
    numero1=int(input())
    print("Selecione o segundo numero\n")
    numero2=int(input())
    resultado=(calculadora(numero1,numero2,numero3))
    print("Resultado:", resultado)
# Out:
# Selecione a operação desejada:
# 1: Soma
# 2: Subtração
# 3: Multiplicação
# 4: Divisão
# 0: Sair
# 9
# Essa opção não existe
#
# Selecione a operação desejada:
# 1: Soma
# 2: Subtração
# 3: Multiplicação
# 4: Divisão
# 0: Sair
# 4
# Selecione o primero numero
#
# 1200
# Selecione o segundo numero
#
# 3
# Resultado: 400.0
# Selecione a operação desejada:
# 1: Soma
# 2: Subtração
# 3: Multiplicação
# 4: Divisão
# 0: Sair
# 0
# Você saiu
