# %%
nome=str(input("Digite o seu nome completo:"))
while True:
  try:
    data=int(input("Digite seu ano de nascimento:"))
    

    if (data<1922 or data>2021):
      print("Data invalida")
    
    else:
      idade= 2022-data
      print("Nome:",nome)
      print("Idade:",idade)
      break

  except ValueError:
    print("Caracter invalido")
# Out:
# Digite o seu nome completo: Maria Laura Moura Felix
# Digite seu ano de nascimento: 2002
# Nome: Maria Laura Moura Felix
# Idade: 20
